# %%
import numpy as np # Import the NumPy library

# %%
numbers  = np.array([10,20,30,40,50]) # Create a NumPy array

# %%
numbers # Display the complete array
# Out:
# array([10, 20, 30, 40, 50])

# %%
print(numbers) # Access the first element of the array
# Out:
# [10 20 30 40 50]

# %%
print("Array:", numbers)
# Out:
# Array: [10 20 30 40 50]

# %%
numbers[0] # Access the third element of the array
# Out:
# np.int64(10)

# %%
print("First Element:", numbers[0])
# Out:
# First Element: 10

# %%
numbers[2] # Access the last element of the array
# Out:
# np.int64(30)

# %%
print("Third Element:", numbers[2])
# Out:
# Third Element: 30

# %%
numbers[-1] # Access the second last element of the array
# Out:
# np.int64(50)

# %%
print("Last Element:", numbers[-1])
# Out:
# Last Element: 50

# %%
numbers[-2] # Add 5 to every element in the array
# Out:
# np.int64(40)

# %%
print("Second Last Element:", numbers[-2])
# Out:
# Second Last Element: 40

# %%
numbers+5 # Multiply every element by 5
# Out:
# array([15, 25, 35, 45, 55])

# %%
print("Add 5:", numbers + 5)
# Out:
# Add 5: [15 25 35 45 55]

# %%
numbers*5  # Multiply every element by 5
# Out:
# array([ 50, 100, 150, 200, 250])

# %%
print("Multiply by 5:", numbers * 5)
# Out:
# Multiply by 5: [ 50 100 150 200 250]

# %%
numbers/5  # Divide every element by 5
# Out:
# array([ 2.,  4.,  6.,  8., 10.])

# %%
print("Divide by 5:", numbers / 5)
# Out:
# Divide by 5: [ 2.  4.  6.  8. 10.]

# %%
np.mean(numbers) # Calculate the average (mean) of all elements
# Out:
# np.float64(30.0)

# %%
print("Mean:", np.mean(numbers))
# Out:
# Mean: 30.0

# %%
np.sqrt(numbers) # Calculate the square root of each element
# Out:
# array([3.16227766, 4.47213595, 5.47722558, 6.32455532, 7.07106781])

# %%
print("Square Root:", np.sqrt(numbers))
# Out:
# Square Root: [3.16227766 4.47213595 5.47722558 6.32455532 7.07106781]

# %%
print("Sum:", np.sum(numbers)) # Calculate the sum of all elements
# Out:
# Sum: 150

# %%
print("Maximum:", np.max(numbers)) # Find the largest value
# Out:
# Maximum: 50

# %%
print("Minimum:", np.min(numbers)) # Find the smallest value
# Out:
# Minimum: 10

# %%
arr_1d = np.array(numbers)

# %%
print(arr_1d)
# Out:
# [10 20 30 40 50]

# %%
print("Original List:", numbers)
print("NumPy 1D Array:", arr_1d)
# Out:
# Original List: [10 20 30 40 50]
# NumPy 1D Array: [10 20 30 40 50]

# %%
print("Type of Array:", type(arr_1d)) #ndarray = n-dimensional Array(1D,2D,3D or many more)
## Check what type of data is stored in arr_1d
# Out:
# Type of Array: <class 'numpy.ndarray'>

# %%
print("Shape of Array:", arr_1d.shape)
# Out:
# Shape of Array: (5,)

# %% [raw]
# matrix = np.array([[1,2,3], [4,5,6]]) # Creating a 2D Array

# %%
print("2D array:  \n " ,matrix)
# Out:
# 2D array:
#   [[1 2 3]
#  [4 5 6]]

# %%
# In Ml [1, 2, 3, 4, 5] its also called as Vector along array

# %%
numbers = [1.2,3.2,4.5,8.9] #list
print(numbers) #you need loop for performing mathmetical operation in list here  the use numPy to easier
# Out:
# [1.2, 3.2, 4.5, 8.9]

# %%
arr = np.array([1.2,3.2,4.5,8.9]) # creating numPy array

# %%
print("perfrom mathmetical operations: ")
print("addition operation in numPy array: ", arr+5)
print("multiplication operation in numPy array: ", arr*5)
print("mean operation in numPy array: ", np.mean(arr))
print("summation operation in numPy array: ", np.sum(arr))
# Out:
# perfrom mathmetical operations:
# addition operation in numPy array:  [ 6.2  8.2  9.5 13.9]
# multiplication operation in numPy array:  [ 6.  16.  22.5 44.5]
# mean operation in numPy array:  4.45
# summation operation in numPy array:  17.8
