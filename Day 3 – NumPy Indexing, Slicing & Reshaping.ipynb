# %%
import numpy as np

# %%
arr = np.array([10,20,30,40,50]) # Create a one-dimensional NumPy array

# %%
print(arr) # Display the original array
# Out:
# [10 20 30 40 50]

# %%
print(arr[0]) # Access the first element of the array
# Out:
# 10

# %%
arr[0]
# Out:
# np.int64(10)

# %%
print(arr[1]) # Access the second element of the array
# Out:
# 20

# %%
print(arr[2]) # Access the third element of the array
# Out:
# 30

# %%
print(arr[4]) # Access the fifth element of the array
# Out:
# 50

# %%
print(arr[10]) #IndexError because array size is 5(index 0 - index 4)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 print(arr[10])
#
# IndexError: index 10 is out of bounds for axis 0 with size 5

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
print (arr[-1]) # Access the last element of the array using negative indexing
# Out:
# 50

# %%
print(arr[-2]) # Access the second last element of the array
# Out:
# 40

# %%
print(arr[-3]) # Access the third last element of the array
# Out:
# 30

# %%
print(arr[-5]) # Access the first element using negative indexing
# Out:
# 10

# %%
print(arr[-6]) #IndexError: index -6 is out of bounds for axis 0 with size 5
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(arr[-6])
#
# IndexError: index -6 is out of bounds for axis 0 with size 5

# %%
slicing = np.array([3.4,5.6,7.8,9.0,6,.7]) 
# Create a one-dimensional NumPy array using floating number

# %%
print(arr)
# Out:
# [10 20 30 40 50]

# %%
print(arr[1:4]) # Extract elements from index 1 up to (but not including) index 4
# Out:
# [20 30 40]

# %%
print(arr[:3])# Extract the first three elements
# Out:
# [10 20 30]

# %%
print(arr[3:])
# Out:
# [40 50]

# %%
step_slicing = np.array([100,120,130,140,150])

# %%
print(arr)
# Out:
# [10 20 30 40 50]

# %%
print(step_slicing[::2])  # Select every second element from the array
# Out:
# [100 130 150]

# %%
print(step_slicing[::-1])
# Out:
# [150 140 130 120 100]

# %%
print(step_slicing[::3]) # Select every third element from the array
# Out:
# [100 140]

# %%
print(step_slicing[1::2]) # Select every second element starting from index 1
# Out:
# [120 140]

# %%
print(step_slicing[2:7:2])# Select every second element between index 2 and index 7 but 7 is not incuded
# Out:
# [130 150]

# %%
print(step_slicing[::-1]) 
# Reverse the array using negative step slicing
# Out:
# [150 140 130 120 100]

# %%
print(step_slicing[::-2])
# Print the array in reverse order without modifying the original array using negative step slicing
# Out:
# [150 130 100]

# %%
print(marks)
# Out:
# [[85 90 88]
#  [78 82 80]
#  [92 89 95]]

# %%
# Create a two-dimensional NumPy array

marks = np.array([
    [85,90,88],
    [78,82,80],
    [92,89,95]
])

# %%
print(marks[0,1]) # Access the second element (row 0, column 1)
# Out:
# 90

# %%
print(marks[1,2]) # Access the element at row 1 and column 2
# Out:
# 80

# %%
print(marks[2,1]) # Access the element at row 2 and column 1
# Out:
# 89

# %%
marks[1,2]
# Out:
# np.int64(80)

# %%
# Create a two-dimensional NumPy array

marks = np.array([
    [85, 98,100],
    [56,78,89],
    [45,67,98]
])

# %%
print(marks)  # Display the original array
# Out:
# [[ 85  98 100]
#  [ 56  78  89]
#  [ 45  67  98]]

# %%
print(marks[0]) # Select the first row
# Out:
# [ 85  98 100]

# %%
print(marks[1]) # Select the second row
# Out:
# [56 78 89]

# %%
print(marks[:,0]) # Select the first column
# Out:
# [85 56 45]

# %%
print(marks[:,1])# Select the second column
# Out:
# [98 78 67]

# %%
print(marks[:,0:2]) # Select the first two columns
# Out:
# [[85 98]
#  [56 78]
#  [45 67]]

# %%
print(marks[0:2,0:2])# Select the first two rows and first two columns
# Out:
# [[85 98]
#  [56 78]]

# %%
#Practice 1 – Basic Indexing
# Tasks
# Print the first element.
# Print the last element using negative indexing.
# Print the third element.
# Print the second last element.

# %%
practice_problems_1 = np.array([5,10,15,20,25,30])

# %%
print(practice_problems_1[0]) #Q1 : Print the first element.
# Out:
# 5

# %%
print(practice_problems_1[-1]) #Q2: Print the last element using negative indexing.
# Out:
# 30

# %%
print(practice_problems_1[2]) #Q3: Print the third element.
# Out:
# 15

# %%
print(practice_problems_1[-2]) #Q4: Print the second last element.
# Out:
# 25

# %%
#Practice 2 – Basic Slicing
# Tasks
# Print the first four elements.
# Print the last three elements.
# Print elements from index 2 to index 5.
# Print every second element.
# Reverse the array.

# %%
practice_problems_2 = np.array([5,10,20,30,40,50,60,70,80])

# %%
print(practice_problems_2[0:4])#Q1: Print the first four elements.
#or
print(practice_problems_2[:4])
# Out:
# [ 5 10 20 30]

# %%
#Q2: Print the last three elements.

print(practice_problems_2[-3:])
#or
print(practice_problems_2[-1:-4:-1])
# Out:
# [60 70 80]

# %%
print(practice_problems_2[2:6]) #Q3: Print elements from index 2 to index 5.
# Out:
# [20 30 40 50]

# %%
print(practice_problems_2[0:8:2]) #Q4: Print every second element.
# Out:
# [ 5 20 40 60]

# %%
print(practice_problems_2[-1:-9:-1]) #Q5: Reverse the array.
# Out:
# [80 70 60 50 40 30 20 10]

# %%
#Practice 3 – 2D Indexing
# Print the first row.
# Print the second row.
# Print the first column.
# Print the second column.
# Print the value 95.
# Print the top-left 2×2 submatrix.Print the first row.
# Print the second row.
# Print the first column.
# Print the second column.
# Print the value 95.
# Print the top-left 2×2 submatrix.

# %%
practice_problems_3 = np.array([
    [85, 90, 88],
    [78, 82, 80],
    [92, 89, 95]
])

# %%
print(practice_problems_3[0])  # Select and display the first row
# Out:
# [85 90 88]

# %%
print(practice_problems_3[1]) # Select and display the second row
# Out:
# [78 82 80]

# %%
# Select and display the first column
print(practice_problems_3[:,0])  # how its work? : means all rows and 0 means column 0
# Out:
# [85 78 92]

# %%
print(practice_problems_3[:,1])  # Select and display the second column
# Out:
# [90 82 89]

# %%
print(practice_problems_3[2,2]) # Access and display the value 95
# Out:
# 95

# %%
print(practice_problems_3[0:2, 0:2]) # Select and display the top-left 2×2 submatrix
# Out:
# [[85 90]
#  [78 82]]
