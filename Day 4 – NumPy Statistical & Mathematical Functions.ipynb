# %%
import numpy as np

# %%
arr = np.array([20,60,79,89,90,])

# %%
sum = np.sum(arr)
print(sum)
# Out:
# 338

# %%
np.sum(arr)
print(arr)
# Out:
# [20 60 79 89 90]

# %%
#calculationg sum of students marks using np.sum() dunction

# %%
marks = np.array([78,90,89,98,78,76])# Create an array containing students' marks

# %%
total_marks = np.sum(marks)# Calculate the total marks

# %%
print(total_marks) # Display the result
# Out:
# 509

# %%
# Practice Problems
practice_sum = np.array([12, 25, 18, 30, 45])
# Print the entire array.
# Calculate the total sum.
# Store the result in a variable named total.
# Print the variable total.

# %%
print(practice_sum)
# Out:
# [12 25 18 30 45]

# %%
total = np.sum(practice_sum)

# %%
print(total)
# Out:
# 130

# %%
#np.mean() function in numpy

# %%
temperature = np.array([10,20,30,40,50])# Create an array containing temperature

# %%
average_temperature = np.mean(temperature)# Calculate the average value of the array

# %%
print(average_temperature)# Display the average temperature
# Out:
# 30.0

# %%
# Practice Problems of np.mean() function
practice_mean = np.array([10, 20, 30, 40, 50])
# Print the entire array.
# Calculate the average value.
# Store the result in a variable named average.
# Print the variable average.

# %%
print(practice_mean)
# Out:
# [10 20 30 40 50]

# %%
average = np.mean(practice_mean)

# %%
print(average)
# Out:
# 30.0

# %%
#np.min() function

# %%
temperature = np.array([36.5, 37.2, 38.1, 36.8, 39.0]) # Create an array containing temperature

# %%
np.min(temperature)  # Find the minimum value in the temperature array
# Out:
# np.float64(36.5)

# %%
minimum_temp = np.min(temperature) # Display the minimum value

# %%
mximum_temp = np.max(temperature) # Display the maximum value

# %%
print(minimum_temp) # Display the minimum temperature value
# Out:
# 36.5

# %%
print(mximum_temp)
# Out:
# 39.0

# %%
# Practice Problems of min() & max() functions
practice = np.array([15, 42, 8, 67, 29, 53])
# Print the entire array.
# Find the minimum value.
# Find the maximum value.
# Store the minimum value in a variable named minimum.
# Store the maximum value in a variable named maximum.
# Print both variables.

# %%
print(practice)
# Out:
# [15 42  8 67 29 53]

# %%
minimum = np.min(practice)

# %%
maximum = np.max(practice)

# %%
print(minimum)
# Out:
# 8

# %%
print(maximum)
# Out:
# 67

# %%
#np.median()

# %%
marks = np.array([85, 90, 88, 78, 92]) # Create an array containing students' marks

# %%
median_mark = np.median(marks)  # Calculate the median value

# %%
print( median_mark) # Display the median value
# Out:
# 88.0

# %%
#  Practice Problems using np.mean() functions
practice_median = np.array([12, 18, 25, 30, 100])
# Print the entire array.
# Calculate the median.
# Store the result in a variable named median_value.
# Print median_value.
# Compare the Mean and Median. Which one is more affected by the value 100?

# %%
print(practice_median)
# Out:
# [ 12  18  25  30 100]

# %%
median_value = np.median(practice_median)

# %%
print(median_value)
# Out:
# 25.0

# %%
mean_value = np.mean(practice_median)

# %%
print(mean_value) #mean is affected by outlier which is 100
# Out:
# 37.0

# %%
#np.std() function ; standard deviation

# %%
marks = np.array([85, 90, 88, 78, 92]) # Create an array containing students' marks

# %%
std_value = np.std(marks) # Calculate the standard deviation

# %%
print(std_value) # Display the standard deviation
# Out:
# 4.882622246293481

# %%
# Practice Problems using np.std() function

practice_std = np.array([12, 15, 18, 20, 25])


# Print the entire array.
# Calculate the standard deviation.
# Store the result in a variable named std_result.
# Print std_result.
# Is the data closely grouped or widely spread? Explain your answer.

# %%
print(practice_std)
# Out:
# [12 15 18 20 25]

# %%
 std_result = np.std(practice_std)

# %%
print(std_result)
# Out:
# 4.427188724235731

# %%
# The data is relatively closely grouped because the standard deviation is low. This indicates that most values are close to the mean and there is no large variation in the dataset.
# Low Standard Deviation → Closely Grouped Data
# High Standard Deviation → Widely Spread Data

# %%
# np.var() (Variance)

# %%
marks = np.array([85, 90, 88, 78, 92]) # Create an array containing students' marks

# %%
variance_value = np.var(marks) # Calculate the variance of the array

# %%
print(variance_value) # Display the variance
# Out:
# 23.839999999999996

# %%
# Practice Problems of np.var() functions

practice_var = np.array([12, 15, 18, 20, 25])

# Print the entire array.
# Calculate the variance.
# Store the result in a variable named variance_result.
# Print variance_result.
# Compare the variance with the standard deviation. What is their relationship?

# %%
print(practice_var)
# Out:
# [12 15 18 20 25]

# %%
variance_result = np.var(practice_var)
sd = np.std(practice_var)

# %%
print(variance_result)
print(sd)
# Out:
# 19.6
# 4.427188724235731

# %%
Variance is the square of the standard deviation. For example, if the standard deviation is 4.42, then the variance is 19.6.

# %%
#np.sqrt() function

# %%
numbers = np.array([25, 49, 64, 81]) 
# Create an array containing perfect square numbers

# %%
square_root = np.sqrt(numbers) # Calculate the square root of each element

# %%
print(square_root)# Display the square root values
# Out:
# [5. 7. 8. 9.]

# %%
# Practice Problems
    
practice_sqrt = np.array([4, 9, 16, 25, 36])

# Try solving these:

# Print the entire array.
# Calculate the square root of all elements.
# Store the result in a variable named sqrt_result.
# Print sqrt_result.
# # Explain why np.sqrt() is important in Machine Learning.

# %%
print(practice_sqrt)
# Out:
# [ 4  9 16 25 36]

# %%
sqrt_result = np.sqrt(practice_sqrt)

# %%
print(sqrt_result) # np.sqrt() returns floating-point values, so integers are displayed as 2., 3., 4., etc. (equivalent to 2.0, 3.0, 4.0).
# Out:
# [2. 3. 4. 5. 6.]

# %%
# np.sqrt() is important in Machine Learning because it is used to calculate standard deviation, Euclidean distance, and other mathematical operations used in data preprocessing and machine learning algorithms.

# %%
#np.power() function

# %%
numbers = np.array([2, 3, 4, 5]) #create 1D array

# %%
square = np.power(numbers, 2) # Raise each element to the power of 2

# %%
print(square) # Display the squared values
# Out:
# [ 4  9 16 25]

# %%
# Practice Problems

practice_power = np.array([2, 4, 6, 8])

# Print the entire array.
# Raise all elements to the power of 2.
# Store the result in a variable named power_result.
# Print power_result.
# Explain why np.power() is useful in Machine Learning.

# %%
print(practice_power)
# Out:
# [2 4 6 8]

# %%
power_result = np.power(practice_power,2)

# %%
print(power_result)
# Out:
# [ 4 16 36 64]

# %%
# np.power() is useful in Machine Learning because it is used to create polynomial features and perform mathematical calculations such as variance and distance formulas.

# %%
#np.abs() function

# %%
numbers = np.array([-8, -3, 5, 10]) # Create an array containing positive and negative numbers

# %%
absolute_values = np.abs(numbers) # Calculate the absolute value of each element

# %%
print(absolute_values) # Display the absolute values
# Out:
# [ 8  3  5 10]

# %%
# Practice Problems using np.abs

practice_abs = np.array([-15, -8, 0, 12, -20])

# Print the entire array.
# Calculate the absolute value of all elements.
# Store the result in a variable named abs_result.
# Print abs_result.
# Explain why np.abs() is useful in Machine Learning.

# %%
print(practice_abs)
# Out:
# [-15  -8   0  12 -20]

# %%
abs_result = np.abs(practice_abs)

# %%
print(abs_result)
# Out:
# [15  8  0 12 20]

# %%
# np.abs() is useful in Machine Learning because it measures the magnitude of errors without considering whether they are positive or negative.

# %%
#np.round() finction

# %%
numbers = np.array([3.14159, 5.67891, 8.23456])  # Create an array containing decimal numbers

# %%
rounded_numbers = np.round(numbers, 2)  
# Round each element to two decimal places

# %%
print(rounded_numbers) # Display the rounded values
# Out:
# [3.14 5.68 8.23]

# %%
# Practice Problems solve to use np.round() function

practice_round = np.array([2.3456, 5.6789, 8.9123, 10.4567])

# Try solving these:

# Print the entire array.
# Round all values to 2 decimal places.
# Store the result in a variable named round_result.
# Print round_result.
# Explain why np.round() is useful in Machine Learning.

# %%
print(practice_round )
# Out:
# [ 2.3456  5.6789  8.9123 10.4567]

# %%
round_result = np.round(practice_round ,2)

# %%
print(round_result)
# Out:
# [ 2.35  5.68  8.91 10.46]

# %%
# np.round() is useful in Machine Learning because it makes numerical results easier to read and present by reducing unnecessary decimal places.

# %%
#np.ceil function

# %%
numbers = np.array([2.3,4.8,6.1 ,7.9]) # Create an array containing decimal numbers

# %%
ceil_value = np.ceil(numbers) # Round each value up to the nearest integer

# %%
print(ceil_value ) # print the ceiling values
# Out:
# [3. 5. 7. 8.]

# %%
# Practice Problems

practice_ceil = np.array([1.2, 3.7, 5.1, 8.9])

# Print the entire array.
# Apply np.ceil() to all elements.
# Store the result in a variable named ceil_result.
# Print ceil_result.
# Explain why np.ceil() is useful in real-life applications.

# %%
print(practice_ceil)
# Out:
# [1.2 3.7 5.1 8.9]

# %%
ceil_result = np.ceil(practice_ceil)

# %%
print(ceil_result)
# Out:
# [2. 4. 6. 9.]

# %%
# np.ceil() is useful because it rounds values up to ensure enough resources are available, such as seats, packets, or memory allocation.

# %%
#np.floor() function

# %%
numbers = np.array([2.3, 4.8, 6.1, 7.9]) #create array

# %%
floor_values = np.floor(numbers) # Round each value down to the next lower integer

# %%
print(floor_values) #print
# Out:
# [2. 4. 6. 7.]

# %%
# Practice Problems

practice_floor = np.array([2.8, 5.4, 7.9, 10.2])

# Print the entire array.
# Apply np.floor() to all elements.
# Store the result in a variable named floor_result.
# Print floor_result.
# Explain why np.floor() is useful in real-life applications.

# %%
print(practice_floor)
# Out:
# [ 2.8  5.4  7.9 10.2]

# %%
 floor_result = np.floor(practice_floor)

# %%
print( floor_resul)
# Out:
# [ 2.  5.  7. 10.]

# %%
# np.floor() is useful because it rounds values down to the nearest integer when only completed or whole units are needed.

# %%
#  axis = 0 (Column-wise)

# %%
# Create a two-dimensional NumPy array
marks = np.array([
    [85, 90, 88],
    [78, 82, 80],
    [92, 89, 95]
])

# %%
column_sum = np.sum(marks, axis=0) # Calculate the sum of each column

# %%
print(column_sum) # print the column-wise sum
# Out:
# [255 261 263]

# %%
#  axis = 1 (Rowwise)

# %%
row_sum = np.sum(marks, axis=1) # Calculate the sum of each row

# %%
print(row_sum) # print the row-wise sum
# Out:
# [263 240 276]

# %%
# Practice Problems on axis = 0

practice_axis = np.array([
     [10, 20, 30],
     [40, 50, 60],
     [70, 80, 90]
 ])

# Try solving these:

# Print the entire array.
# Calculate the sum of each row.
# Store the result in a variable named row_sum.
# Print row_sum.
# Explain the difference between axis=0 and axis=1.

# %%
print(practice_axis)
# Out:
# [[10 20 30]
#  [40 50 60]
#  [70 80 90]]

# %%
row_sum = np.sum(practice_axis,axis=1)

# %%
print(row_sum)
# Out:
# [ 60 150 240]

# %%
# axis=0 performs calculations on columns, while axis=1 performs calculations on rows.

# %%
# Real Machine Learning Examples

# %%
# Example 1 – Student Marks Analysis
# Create a dataset of student marks
marks = np.array([
    [85, 90, 88],
    [78, 82, 80],
    [92, 89, 95]
])
# Calculate the total marks of each student
# Calculate the average marks of each subject
# Find the highest mark in the dataset
# Find the lowest mark in the dataset

# %%
student_total_marks = np.sum(marks,axis=1)

# %%
print(student_total_marks)
# Out:
# [263 240 276]

# %%
student_average_mark = np.mean(marks,axis=1)

# %%
print(student_average_mark)
# Out:
# [87.66666667 80.         92.        ]

# %%
print(np.max(marks))
# Out:
# 95

# %%
print(np.min(marks))
# Out:
# 78

# %%
# Example 2 – Machine Learning Feature Analysis of Height Dataset

height = np.array([160, 165, 170, 175, 180])
# Calculate the average height
# Calculate the standard deviation
# Calculate the variance

# %%
print(np.mean(height))
# Out:
# 170.0

# %%
print(np.std(height))
# Out:
# 7.0710678118654755

# %%
print(np.var(height))
# Out:
# 50.0

# %%
# Example 3 – Krishok Bondhu App Analysis of rice production

production = np.array([120.456, 140.782, 135.219])

# Round the production values to two decimal places

# %%
print(np.round(production,2))
# Out:
# [120.46 140.78 135.22]

# %%
# Example 4 – Mean Absolute Error (MAE)

prediction = np.array([90, 85, 80])
actual = np.array([88, 90, 82])

# Calculate the absolute error
# Calculate the mean absolute error

# %%
error = np.abs(prediction - actual)

# %%
print(error)
# Out:
# [2 5 2]

# %%
print(np.mean(error))
# Out:
# 3.0

# %%
# Example 5 – Batch Size Calculation
# let
# 1000 Images and batch size is 128
# Calculate the required number of batches

# %%
print(np.ceil(1000 / 128))
# Out:
# 8.0

# %%
#Example 6 – Feature Scaling(Square Root Transformation)
feature = np.array([4, 9, 16, 25])

# Apply square root transformation

# %%
print(np.sqrt(feature))
# Out:
# [2. 3. 4. 5.]

# %%
# Mixed Practice Challenge
marks = np.array([
    [85, 90, 88],
    [78, 82, 80],
    [92, 89, 95]
])

# Practice Questions


# Part A – Basic Operations

# Print the entire array.
# Print the shape of the array.
# Print the number of dimensions.
# Print the data type.

# Part B – Statistical Functions

# Calculate the total sum of all elements.
# Calculate the average of all elements.
# Find the maximum value.
# Find the minimum value.
# Find the median.
# Calculate the standard deviation.
# Calculate the variance.

# Part C – Mathematical Functions

# Calculate the square root of every element.
# Square every element using np.power().
# Create the following array and find its absolute values.

difference = np.array([-5, -3, 2, -8, 6])

# Part D – Rounding Functions

# Create the following array.
 
numbers = np.array([3.4567, 8.9231, 5.1289])

# Round all numbers to 2 decimal places.
# Apply np.ceil().
# Apply np.floor().

# Part E – Axis Operations

# Calculate the sum of each column.
# Calculate the sum of each row.
# Calculate the average of each column.
# Calculate the average of each row.

# Part F – Concept Questions

# Why is np.mean() important in Machine Learning?
# When should we use np.median() instead of np.mean()?
# What does Standard Deviation tell us?
# What is the relationship between Variance and Standard Deviation?
# What is the difference between np.ceil() and np.floor()?
# What is the difference between axis=0 and axis=1?

# %%
#  Solution of Part A – Basic Operations

# %%
print(marks) #print the entire array.
# Out:
# [[85 90 88]
#  [78 82 80]
#  [92 89 95]]

# %%
print(np.shape( marks)) #print the shape of the array.
# Out:
# (3, 3)

# %%
print(marks.ndim) #print the number of dimensions.
# Out:
# 2

# %%
print(marks.dtype) # print data type
# Out:
# int64

# %%
# Solution of Part B – Statistical Functions

# %%
print(np.sum(marks)) # Calculate the total sum of all elements
# Out:
# 779

# %%
print(np.mean(marks)) #Calculate the average of all elements

# %%
print(np.max(marks)) #Find the maximum value
# Out:
# 95

# %%
print(np.min(marks)) #Find the minimum value
# Out:
# 78

# %%
print(np.mean(marks)) #Find the median
# Out:
# 86.55555555555556

# %%
print(np.std(marks)) #Calculate the standard deviation

# %%
print(np.var(marks)) #Calculate the variance
# Out:
# 28.913580246913583

# %%
#Solution of Part C – Mathematical Functions

# %%
print(np.sqrt(marks)) #Calculate the square root of every element
# Out:
# [[9.21954446 9.48683298 9.38083152]
#  [8.83176087 9.05538514 8.94427191]
#  [9.59166305 9.43398113 9.74679434]]

# %%
print(np.power(marks, 2)) #Square every element
# Out:
# [[7225 8100 7744]
#  [6084 6724 6400]
#  [8464 7921 9025]]

# %%
print(np.abs(difference)) #Find the absolute values
# Out:
# [5 3 2 8 6]

# %%
# Solution of Part D – Rounding Functions

# %%
print(numbers)
# Out:
# [3.4567 8.9231 5.1289]

# %%
print(np.round(numbers, 2)) #Round to 2 decimal places
# Out:
# [3.46 8.92 5.13]

# %%
print(np.ceil(numbers)) #Apply np.ceil()
# Out:
# [4. 9. 6.]

# %%
print(np.floor(numbers)) #Apply np.floor()
# Out:
# [3. 8. 5.]

# %%
#Solution of Part E – Axis Operations

# %%
print(np.sum(marks,axis=0)) #Calculate the sum of each column
# Out:
# [255 261 263]

# %%
print(np.sum(marks,axis=1)) #Calculate the sum of each row
# Out:
# [263 240 276]

# %%
print(np.mean(marks,axis=0)) #Calculate the average of each column
# Out:
# [85.         87.         87.66666667]

# %%
print(np.mean(marks,axis=1)) #Calculate the average of each row
# Out:
# [87.66666667 80.         92.        ]
